# %%
from pop import delay, Oled, Sht20, Switches
display = Oled()
sht = Sht20()
btn = Switches()

# 초기화
display.init()
display.setTextSize(s=1)
display.ClearDisplay()

while True:
    temp = sht.readTemp()
    humi = sht.readTemp()
    
    display.clearDisplay()
    display.setCursor(10, 10)
    
    display.print("Temp : ", temp)
    display.print("humi : ", humi)
    
    display.display()
    delay(1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-139789b8b123> in <module>
#       5
#       6 # 초기화
# ----> 7 oled.init()
#       8 display.setTextSize(s=1)
#       9 oled.ClearDisplay()
#
# NameError: name 'oled' is not defined
