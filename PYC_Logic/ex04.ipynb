# %% [markdown]
# # ex04 Notebook
# VSCode에서 이 파일을 열고 셀을 클릭한 뒤 `Shift+Enter`로 실행하세요.

# %%
import pop
print('pop import ok')

# %%
from pop import Leds, delay
led = Leds()
led.allOn()
delay(20000)
led.allOff()
print('led test done')
# Out:
# led test done
